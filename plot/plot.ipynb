# %%
import sys

import matplotlib
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D

import numpy as np
from numpy.random import randn
from scipy import array, newaxis

# %%
#figure 1: méthode implicite call
plot = np.loadtxt(r"D:\Projet-C\result\call_implicite.txt")
x_call_i = plot[:,0]
y_call_i = plot[:,1]
z_call_i = plot[:,2]
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_trisurf(x_call_i, y_call_i, z_call_i, cmap=cm.jet, linewidth=0)
ax.view_init(20, 230)
fig.tight_layout()
plt.title("Surface de prix d'une option call (méthode implicite)")
plt.xlabel("S")
plt.ylabel("T - t")
ax.set_zlabel('C(S,t)')
plt.show()

# %%
#figure 2: méthode implicite-Crank Nicolson call
plot = np.loadtxt(r"D:\Projet-C\result\call_imp_crank.txt")
x_call_ic = plot[:,0]
y_call_ic = plot[:,1]
z_call_ic = plot[:,2]
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_trisurf(x_call_ic, y_call_ic, z_call_ic, cmap=cm.jet, linewidth=0)
ax.view_init(20, 230)
fig.tight_layout()
plt.title("Surface de prix d'une option call (méthode implicite-Crank Nicolson)")
plt.xlabel("S")
plt.ylabel("T - t")
ax.set_zlabel('C(S,t)')
plt.show()

# %%
#figure 3: méthode implicite put
plot = np.loadtxt(r"D:\Projet-C\result\put_implicite.txt")
x_put_i = plot[:,0]
y_put_i = plot[:,1]
z_put_i = plot[:,2]
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_trisurf(x_put_i, y_put_i, z_put_i, cmap=cm.jet, linewidth=0)
ax.view_init(20, 40)
fig.tight_layout()
plt.title("Surface de prix d'une option put (méthode implicite)")
plt.xlabel("S")
plt.ylabel("T - t")
ax.set_zlabel('P(S,t)')
plt.show()

# %%
#figure 4: méthode implicite-Crank Nicolson put
plot = np.loadtxt(r"D:\Projet-C\result\put_imp_crank.txt")
x_put_ic = plot[:,0]
y_put_ic = plot[:,1]
z_put_ic = plot[:,2]
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_trisurf(x_put_ic, y_put_ic, z_put_ic, cmap=cm.jet, linewidth=0)
ax.view_init(20, 40)
fig.tight_layout()
plt.title("Surface de prix d'une option put (méthode implicite-Crank Nicolson)")
plt.xlabel("S")
plt.ylabel("T - t")
ax.set_zlabel('P(S,t)')
plt.show()
